# %% [markdown]
# #  Python Sets – Practice Questions

# %% [markdown]
# ### Q1
# Create a set from the list below and print only the unique values.
#
# ```python
# data = [10, 20, 20, 30, 40, 40]
# ```

# %%
# write your code here
data = {10, 20, 20, 30, 40, 40}
print(data)
# Out:
# {40, 10, 20, 30}

# %% [markdown]
# ### Q2
# What will be the output? Explain why.
#
# ```python
# s = {1, 2, 3, 3, 2}
# print(s)
# ```

# %%
# write your code here
s = {1, 2, 3, 3, 2}
print(s)  #The output is the unique values beacuse in set u can only store unique values.
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Q3
# Create an empty set and add numbers from 1 to 5 using a loop.

# %%
# write your code here
number=set()

for i in range(1,6):
  number.add(i)
print(number)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### Q4
# Why does this code give an error? Fix it.
#
# ```python
# s = {}
# s.add(10)
# ```

# %%
# write your code here
s=set() #the correct way to make the empty list is X=set() Where X is any Name which we use to assign the set.
s.add(10)

# %% [markdown]
# ### Q5
# Given:
# ```python
# A = {2, 4, 6, 8}
# B = {4, 8, 12}
# ```
# Find Union, Intersection, A-B

# %%
# write your code here
A = {2, 4, 6, 8}
B = {4, 8, 12}
print(f'Union={A|B},Intersection{A.intersection(B)}')
# Out:
# Union={2, 4, 6, 8, 12},Intersection{8, 4}

# %% [markdown]
# ### Q6
# Check whether 15 exists in the set {5, 10, 15, 20}.

# %%
# write your code here

if 15 in {5, 10, 15, 20}:
  print("mil gya")
else:
  print("nhi mil gya")
# Out:
# mil gya

# %% [markdown]
# ### Q7
# Remove element 30 safely from {10, 20, 30, 40}.

# %%
# write your code here
Set={10, 20, 30, 40}
Set.remove(30)
print(Set)
# Out:
# {40, 10, 20}

# %% [markdown]
# ### Q8
# Count unique elements in:
# ```python
# nums = [1, 2, 2, 3, 4, 4, 5]
# ```

# %%
# write your code here

nums = [1, 2, 2, 3, 4, 4, 5]
Num=set(nums)
count=0
for i in Num:
  count=count+1
print(count)
# Out:
# 5

# %% [markdown]
# ### Q9
# What will be the output?
# ```python
# s = {10, 20, 30}
# s.add(20)
# print(len(s))
# ```

# %%
# write your code here
s = {10, 20, 30}
s.add(20)
print(len(s)) #the ken of the set will remains same beacuse set u can store only unique elements.
# Out:
# 3

# %% [markdown]
# ### Q10
# Can a set contain a list? Why?
# ```python
# s = {1, 2, [3, 4]}
# ```

# %% [markdown]
# A set **cannot** contain a list because lists are **mutable**, and set elements must be **immutable and hashable**.
# Use a tuple instead if you need a list‑like element in a set.

# %% [markdown]
# ### Q11
# Convert {100, 200, 300} into list and print first element.

# %%
# write your code here

set1={100, 200, 300}

print(set1)

l1=list(set1)


l1[0]
# Out:
# {200, 100, 300}
# 200

# %% [markdown]
# ### Q12
# Students in two classes:   #union
# ```python
# class_A = {'Aman','Riya','Karan','Neha'}
# class_B = {'Neha','Simran','Aman'}
# ```

# %%
# write your code here
class_A = {'Aman','Riya','Karan','Neha'}
class_B = {'Neha','Simran','Aman'}
print(class_A|class_B)
# Out:
# {'Riya', 'Neha', 'Simran', 'Karan', 'Aman'}

# %% [markdown]
# ### Q13
# Find unique characters in:
# ```python
# text = 'programming'
# ```

# %%
# write your code here

text = 'programming'
Set=set(text)
print(Set)
# Out:
# {'r', 'n', 'g', 'i', 'a', 'm', 'o', 'p'}

# %% [markdown]
# ### Q14
# Remove duplicate words from:
# ```python
# sentence = 'python is easy and python is powerful'
# ```

# %%
# write your code here

sentence = 'python is easy and python is powerful'

words = sentence.split()
unique_words = []
for w in words:
    if w not in unique_words:
        unique_words.append(w)

result = " ".join(unique_words)
print(result)
# Out:
# python is easy and powerful

# %% [markdown]
# ### Q15
# What is the output?
# ```python
# s = set('hello')
# print(s)
# ```

# %%
# write your code here
s = set('hello')
print(s)
# Out:
# {'o', 'e', 'h', 'l'}
