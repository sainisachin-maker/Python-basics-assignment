# %% [markdown]
# #  Python Sets – Practice Questions

# %% [markdown]
# ### Q1
# Create a set from the list below and print only the unique values.
#
# ```python
# data = [10, 20, 20, 30, 40, 40]
# ```

# %%
# write your code here
data = [10, 20, 20, 30, 40, 40]
Set=set(data)
print(Set)
# Out:
# {40, 10, 20, 30}

# %% [markdown]
# ### Q2
# What will be the output? Explain why.
#
# ```python
# s = {1, 2, 3, 3, 2}
# print(s)
# ```

# %%
# write your code here
s = {1, 2, 3, 3, 2}
print(s)

#The output of this code is {1, 2, 3} because in set duplicate value will remove and written as an unique value
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Q3
# Create an empty set and add numbers from 1 to 5 using a loop.

# %%
# write your code here
Set=set()
i=1
for i in range(1,6):
  Set.add(i)
print(Set)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### Q4
# Why does this code give an error? Fix it.
#
# ```python
# s = {}
# s.add(10)
# ```

# %%
# write your code here
#Here s={} and python read it as an dictonary so we write this as given below
s = set()
s.add(10)
print(s)
# Out:
# {10}

# %% [markdown]
# ### Q5
# Given:
# ```python
# A = {2, 4, 6, 8}
# B = {4, 8, 12}
# ```
# Find Union, Intersection, A-B

# %%
# write your code here
A = {2, 4, 6, 8}
B = {4, 8, 12}
print(A|B)
print(A.intersection(B))
print(A-B)
# Out:
# {2, 4, 6, 8, 12}
# {8, 4}
# {2, 6}

# %% [markdown]
# ### Q6
# Check whether 15 exists in the set {5, 10, 15, 20}.

# %%
# write your code here
Set= {5, 10, 15, 20}
for i in Set:
  if i==15:
    print('Y')
  else:
    continue

# %% [markdown]
# ### Q7
# Remove element 30 safely from {10, 20, 30, 40}.

# %%
# write your code here

Set={10, 20, 30, 40}
Set.remove(30)
print(Set)
# Out:
# {40, 10, 20}

# %% [markdown]
# ### Q8
# Count unique elements in:
# ```python
# nums = [1, 2, 2, 3, 4, 4, 5]
# ```

# %%
# write your code here
nums = [1, 2, 2, 3, 4, 4, 5]
Set=set(nums)

print(Set)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### Q9
# What will be the output?
# ```python
# s = {10, 20, 30}
# s.add(20)
# print(len(s))
# ```

# %%
# write your code here

#the len of the set is 3, 20 is add to the set but 20 is already presnt in the set so its not repeat in the set so the len of the set remains same.

# %% [markdown]
# ### Q10
# Can a set contain a list? Why?
# ```python
# s = {1, 2, [3, 4]}
# ```

# %%
# write your code here
#NO

# %% [markdown]
# ### Q11
# Convert {100, 200, 300} into list and print first element.

# %%
# write your code here

Set={100, 200, 300}
List=list(Set)
print(List)
List[0]
# Out:
# [200, 100, 300]
# 200

# %% [markdown]
# ### Q12
# Students in two classes:
# ```python
# class_A = {'Aman','Riya','Karan','Neha'}
# class_B = {'Neha','Simran','Aman'}
# ```

# %%
# write your code here
class_A = {'Aman','Riya','Karan','Neha'}
class_B = {'Neha','Simran','Aman'}

class_A|class_B
# Out:
# {'Aman', 'Karan', 'Neha', 'Riya', 'Simran'}

# %% [markdown]
# ### Q13
# Find unique characters in:
# ```python
# text = 'programming'
# ```

# %%
# write your code here
text = 'programming'
text=set(text)
print(text)
# Out:
# {'r', 'n', 'o', 'i', 'p', 'a', 'g', 'm'}

# %% [markdown]
# ### Q14
# Remove duplicate words from:
# ```python
# sentence = 'python is easy and python is powerful'
# ```

# %%
# write your code here
sentence = 'python is easy and python is powerful'
sentence=sentence.split()
Set=set(sentence)
print(Set)
# Out:
# {'easy', 'and', 'powerful', 'python', 'is'}

# %% [markdown]
# ### Q15
# What is the output?
# ```python
# s = set('hello')
# print(s)
# ```

# %%
# write your code here
# this is the output{'l', 'e', 'o', 'h'}
# Out:
# {'l', 'e', 'o', 'h'}
